# %%
from IPython.core.display import display, HTML 
display(HTML("<style>.container { width:95% !important; }div.output_wrapper .output { padding-left: 14px; }</style>"))
# Out:
# <style>.container { width:95% !important; }div.output_wrapper .output { padding-left: 14px; }</style>

# %%
import pickle
import os
from pathlib import Path
import re
#import mdfreader
import time

import pandas as pd
import json

# %%
def convert_to_UNC(path):
    '''Converts the path to a different format -- this solves the
    issue of the paths being too long to be processed (>255chars)'''
    path = Path(path).absolute().as_posix()
    if ':' in path:
        path = path.replace(':', '$')
        return Path('//?/UNC/localhost/' + path)
    else:
        path = path.replace('//', '')
        return Path('//?/UNC/' + path)

# %%
df_htoe = pd.read_csv('htoe_raw-channels.txt', header=None, names=['signal_names'])

# %%
df_htoe.head()
# Out:
#                 signal_names
# 0     $ActiveCalibrationPage
# 1  $ActiveCalibrationPage_1_
# 2  $ActiveCalibrationPage_2_
# 3  $ActiveCalibrationPage_3_
# 4  $ActiveCalibrationPage_4_

# %%
def process_data(x):
    
    def get_suffixes(x):
        fmtre = re.search("(\_([0-9])+)+$", x)
        if fmtre is None:
            return "None"
        else:
            return fmtre.group()
        
    def signal_column_check(data):
        if True in data:
            return True
        else:
            return False
        
    data = x
        
    # initial processing
    data.signal_names = data.signal_names.str.lower()
    data.signal_names = data.signal_names.apply(lambda x: re.sub('\W+','', x))
    data.signal_names = data.signal_names.apply(lambda x: re.sub(' ','', x))

    data["ld"] = pd.notna(data.signal_names.str.extract("(_ld$)"))
    data["dut"] = pd.notna(data.signal_names.str.extract("(_dut$)"))
    data.signal_names = data.signal_names.apply(lambda x: re.sub('(_dut$|_ld$)', '', x))
    
    data["pure"] = data.apply(lambda x: (x['dut'] == False | x['ld'] == False), axis=1)
    
    # signal suffixes
    data.signal_names = data.signal_names.apply(lambda x: re.sub('\_$', '', x))
    data["signal_suffix"] = data.signal_names.apply(lambda x: get_suffixes(x))
    data.signal_suffix = data.signal_suffix.apply(lambda x: re.sub("^\_","", x))
    data.signal_suffix = data.signal_suffix.apply(lambda x: re.sub("\_$","", x))
    data.signal_names = data.signal_names.apply(lambda x: re.sub('(\_([0-9])+)+$','', x))
    
    data[["dut_suffix", "ld_suffix", "pure_suffix"]] = "None"
    data.loc[data['dut'] == True, 'dut_suffix'] = data["signal_suffix"]
    data.loc[data['ld'] == True, 'ld_suffix'] = data["signal_suffix"]
    data.loc[data['pure'] == True, 'pure_suffix'] = data["signal_suffix"]
    
    columns = data.columns
    
    data = pd.DataFrame(data.groupby(by = ['signal_names'], as_index = False)
                     [columns[1:]].agg(["unique"]))
    data = data.reset_index()
    data = data.rename(columns = {"unique" : ""})
    data.columns = columns
        
    data.dut = data.dut.apply(lambda x:  signal_column_check(x))
    data.ld = data.ld.apply(lambda x:  signal_column_check(x))
    data.pure = data.pure.apply(lambda x:  signal_column_check(x))


    return data

# %%
import inspect as i
import sys
sys.stdout.write(i.getsource(get_suffixes))
# Out:
# def get_suffixes(x):
#     fmtre = re.search("(\_([0-9])+)+$", x)
#     if fmtre is None:
#         return "None"
#     else:
#         return fmtre.group()

# %%
df_htoe.head(10)
# Out:
#                  signal_names
# 0      $ActiveCalibrationPage
# 1   $ActiveCalibrationPage_1_
# 2   $ActiveCalibrationPage_2_
# 3   $ActiveCalibrationPage_3_
# 4   $ActiveCalibrationPage_4_
# 5  $ActiveCalibrationPage_4_4
# 6   $ActiveCalibrationPage_6_
# 7             $CalibrationLog
# 8          $CalibrationLog_1_
# 9          $CalibrationLog_2_

# %%
df_htoe_processed = process_data(df_htoe)

# %%
df_htoe_processed.head(20)
# Out:
#                                       signal_names     ld    dut  pure  \
# 0                            activecalibrationpage  False  False  True
# 1                                       actual_rpm  False  False  True
# 2                                    actual_torque  False  False  True
# 3           actualvaluevolumeflowcoolantetractsys1  False  False  True
# 4                             aliv_avl_dt_mot_trct  False  False  True
# 5                                            alpha  False  False  True
# 6                               avl_dirrt_mot_trct  False  False  True
# 7                                     avl_opmo_mot  False  False  True
# 8                                avl_opmo_mot_trct  False  False  True
# 9                                 avl_rpm_mot_trct  False  False  True
# 10                               avl_temp_dcdc_cnv  False  False  True
# 11                               avl_temp_mot_trct  False  False  True
# 12                        avl_temp_pwostg_engmg_el  False  False  True
# 13                               avl_torq_mot_trct  False  False  True
# 14                       battery_simulator_voltage  False  False  True
# 15                          bender_iso_measurement  False  False  True
# 16            bmw_ag_ofsemmecl_rc_bmw_ag_ofsemmecl  False  False  True
# 17         bmw_ag_ofsemmecl_rc_bmw_ag_ofsemmecl_qi  False  False  True
# 18  bmw_ag_ofshifrqsiginj_rc_bmw_ag_ofshifrqsiginj  False  False  True
# 19    bmw_ag_sftyofsemmecl_rc_bmw_ag_sftyofsemmecl  False  False  True
#
#                  signal_suffix dut_suffix ld_suffix  \
# 0   [None, 1, 2, 3, 4, 4_4, 6]     [None]    [None]
# 1                       [None]     [None]    [None]
# 2                       [None]     [None]    [None]
# 3                       [None]     [None]    [None]
# 4                       [None]     [None]    [None]
# 5                       [None]     [None]    [None]
# 6                       [None]     [None]    [None]
# 7                          [1]     [None]    [None]
# 8                       [None]     [None]    [None]
# 9                       [None]     [None]    [None]
# 10                      [None]     [None]    [None]
# 11                      [None]     [None]    [None]
# 12                      [None]     [None]    [None]
# 13                      [None]     [None]    [None]
# 14                      [None]     [None]    [None]
# 15                      [None]     [None]    [None]
# 16     [None, 3, 3_3, 5, 7, 8]     [None]    [None]
# 17             [None, 3, 5, 8]     [None]    [None]
# 18                      [None]     [None]    [None]
# 19   [None, 3, 3_3, 5, 5_5, 8]     [None]    [None]
#
#                    pure_suffix
# 0   [None, 1, 2, 3, 4, 4_4, 6]
# 1                       [None]
# 2                       [None]
# 3                       [None]
# 4                       [None]
# 5                       [None]
# 6                       [None]
# 7                          [1]
# 8                       [None]
# 9                       [None]
# 10                      [None]
# 11                      [None]
# 12                      [None]
# 13                      [None]
# 14                      [None]
# 15                      [None]
# 16     [None, 3, 3_3, 5, 7, 8]
# 17             [None, 3, 5, 8]
# 18                      [None]
# 19   [None, 3, 3_3, 5, 5_5, 8]

# %%
df_htoe_processed.to_csv(r'htoe_processed.csv', index = False)

# %%
df_mech = pd.read_csv('mech_raw-channels.txt', header=None, names=['signal_names'])
df_mech_processed = process_data(df_mech)
df_mech_processed.head()
# Out:
#                                   signal_names     ld    dut   pure  \
# 0                        activecalibrationpage  False  False   True
# 1       actualvaluevolumeflowcoolantetractsys1   True   True  False
# 2             aliv_combinedchargerunit100msno1   True   True  False
# 3              aliv_combinedchargerunit10msno1   True   True  False
# 4  aliv_tractionemachineelectronic1time10msno1   True   True  False
#
#   signal_suffix dut_suffix ld_suffix   pure_suffix
# 0  [None, 4, 9]     [None]    [None]  [None, 4, 9]
# 1        [None]     [None]    [None]        [None]
# 2        [None]     [None]    [None]        [None]
# 3        [None]     [None]    [None]        [None]
# 4        [None]     [None]    [None]        [None]

# %%
df_mech_processed.to_csv(r'mech_processed.csv', index = False)

# %%
df_ptce = pd.read_csv('ptce_raw-channels.txt', header=None, names=['signal_names'])
df_ptce_processed = process_data(df_ptce)
df_ptce_processed.head(10)
# Out:
#                                   signal_names     ld    dut   pure  \
# 0      21dcurrentdirectcurrentheat1actualvalue   True   True  False
# 1                        activecalibrationpage  False  False   True
# 2       actualvaluevolumeflowcoolantetractsys1   True   True  False
# 3       actualvaluevolumeflowcoolantetractsys2   True   True  False
# 4                         air_saturation_value  False  False   True
# 5             aliv_combinedchargerunit100msno1   True   True  False
# 6              aliv_combinedchargerunit10msno1   True   True  False
# 7  aliv_tractionemachineelectronic1time10msno1   True   True  False
# 8                                        alpha  False  False   True
# 9                                avl_cutil_pcu   True   True  False
#
#        signal_suffix dut_suffix ld_suffix        pure_suffix
# 0             [None]     [None]    [None]             [None]
# 1  [None, 4, 4_4, 6]     [None]    [None]  [None, 4, 4_4, 6]
# 2             [None]     [None]    [None]             [None]
# 3             [None]     [None]    [None]             [None]
# 4             [None]     [None]    [None]             [None]
# 5             [None]     [None]    [None]             [None]
# 6             [None]     [None]    [None]             [None]
# 7             [None]     [None]    [None]             [None]
# 8             [None]     [None]    [None]             [None]
# 9             [None]     [None]    [None]             [None]

# %%
df_ptce_processed.to_csv(r'ptce_processed.csv', index = False)
